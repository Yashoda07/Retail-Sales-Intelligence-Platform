# %%
import pandas as pd

df = pd.read_csv("../data/cleaned/global_superstore_cleaned.csv")

# df["order_date"] = pd.to_datetime(df["order_date"])
# df["ship_date"] = pd.to_datetime(df["ship_date"])

# %%
# Business Question 1
# What are the overall business KPIs?

print("Total Sales:", df["sales"].sum())
print("Total Profit:", df["profit"].sum())
print("Total Orders:", df["order_id"].nunique())
print("Total Customers:", df["customer_id"].nunique())
print("Average Delivery Days:", df["delivery_days"].mean())
# Out:
# Total Sales: 2297200.8603
# Total Profit: 286397.0217
# Total Orders: 5009
# Total Customers: 793
# Average Delivery Days: 3.958174904942966

# %%
# Business Question 1
# Which product categories generate the highest sales and profit?
category_analysis = (
    df.groupby("category")[["sales", "profit"]]
      .sum()
      .sort_values(by="sales", ascending=False)
)

category_analysis
# Out:
#                        sales       profit
# category
# Technology       836154.0330  145454.9481
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008

# %%
import matplotlib.pyplot as plt

# %%
ax = category_analysis["sales"].plot(kind="bar")

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")

for container in ax.containers:
    ax.bar_label(container, fmt="%.0f")

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
category_analysis
# Out:
#                        sales       profit
# category
# Technology       836154.0330  145454.9481
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008

# %%
# Business Question 3
# Which sub-categories are losing money?

subcategory_analysis = (
    df.groupby("sub_category")[["sales", "profit"]]
      .sum()
      .sort_values(by="profit")
)

subcategory_analysis
# Out:
#                     sales      profit
# sub_category
# Tables        206965.5320 -17725.4811
# Bookcases     114879.9963  -3472.5560
# Supplies       46673.5380  -1189.0995
# Fasteners       3024.2800    949.5182
# Machines      189238.6310   3384.7569
# Labels         12486.3120   5546.2540
# Art            27118.7920   6527.7870
# Envelopes      16476.4020   6964.1767
# Furnishings    91705.1640  13059.1436
# Appliances    107532.1610  18138.0054
# Storage       223843.6080  21278.8264
# Chairs        328449.1030  26590.1663
# Binders       203412.7330  30221.7633
# Paper          78479.2060  34053.5693
# Accessories   167380.3180  41936.6357
# Phones        330007.0540  44515.7306
# Copiers       149528.0300  55617.8249

# %%
tables = df[df["sub_category"] == "Tables"]
tables[["sales", "discount", "profit"]].describe()
# Out:
#              sales    discount       profit
# count   319.000000  319.000000   319.000000
# mean    648.794771    0.261285   -55.565771
# std     615.774655    0.169622   230.565006
# min      24.368000    0.000000 -1862.312400
# 25%     244.006000    0.200000  -122.829300
# 50%     447.840000    0.300000   -31.372200
# 75%     872.170000    0.400000    33.851700
# max    4297.644000    0.500000   629.010000

# %%
tables.groupby("discount")[["sales", "profit"]].mean()
# Out:
#                sales      profit
# discount
# 0.00      994.149444  184.393051
# 0.20      639.862423   -4.275465
# 0.30      466.336111  -63.006067
# 0.40      608.192080 -215.831957
# 0.45      498.634000 -226.646464
# 0.50      379.861389 -239.316314

# %%
region_analysis = (
    df.groupby("region")[["sales", "profit"]]
      .sum()
      .sort_values(by="profit", ascending=False)
)

region_analysis
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 region_analysis = (
# ----> 2     df.groupby("region")[["sales", "profit"]]
#       3       .sum()
#       4       .sort_values(by="profit", ascending=False)
#       5 )
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# ...

# %%
df.columns
# Out:
# Index(['<<<<<<< HEAD'], dtype='str')
